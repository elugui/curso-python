# %% [markdown]
# # Aula 06 – Concatenação de Dados com Pandas
#
# ## Objetivo
# Aprender a unir múltiplos datasets (mensais) para formar uma base consolidada.
#
# ## O que será abordado:
# - concat()
# - pivot()
# - União de datasets
# - Estruturação de bases maiores
# - Boas práticas

# %% [markdown]
# ## 1. Importando bibliotecas

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## 2. Carregando os dados
# Vamos carregar três bases:
# - Dezembro
# - Janeiro
# - Fevereiro

# %%
caminho_arquivo = r"C:\Users\Joao.Maria\Documents\curso-python_joao_pedro\Base\Base_analitica_vendas_periodo.xlsx"

# %%
base_venda_dezembro = pd.read_excel(caminho_arquivo, sheet_name="Dez")
base_venda_janeiro = pd.read_excel(caminho_arquivo, sheet_name="Jan")
base_venda_fevereiro = pd.read_excel(caminho_arquivo, sheet_name="Fev")

# %% [markdown]
# ## 3. Analisando estrutura das bases

# %%
base_venda_dezembro.columns
# Out:
# Index(['DATA', 'CODIGOCLIENTE', 'DESCRICAOCLIENTE', 'CODIGOGRUPOPRODUTO',
#        'DESCRICAOGRUPOPRODUTO', 'CODIGOPRODUTO', 'NOMEPRODUTO',
#        'TIPOFATURAMENTO', 'DESCRICAOTIPOFATURAMENTO', 'VOLUME',
#        'VALORLIQUIDO'],
#       dtype='str')

# %%
base_venda_janeiro.columns
# Out:
# Index(['DATAEMISSAO', 'CODIGOCLIENTE', 'DESCRICAOCLIENTE',
#        'CODIGOGRUPOPRODUTO', 'DESCRICAOGRUPOPRODUTO', 'CODIGOPRODUTO',
#        'NOMEPRODUTO', 'TIPOFATURAMENTO', 'DESCRICAOTIPOFATURAMENTO', 'VOLUME',
#        'VALORLIQUIDO'],
#       dtype='str')

# %%
base_venda_fevereiro.columns
# Out:
# Index(['DATAEMISSAO', 'CODIGOCLIENTE', 'DESCRICAOCLIENTE',
#        'CODIGOGRUPOPRODUTO', 'DESCRICAOGRUPOPRODUTO', 'CODIGOPRODUTO',
#        'NOMEPRODUTO', 'TIPOFATURAMENTO', 'DESCRICAOTIPOFATURAMENTO', 'VOLUME',
#        'VALORLIQUIDO'],
#       dtype='str')

# %% [markdown]
# ## 4. Concatenando os datasets

# %%
base_venda_dezembro["MES"] = "Dezembro"
base_venda_janeiro["MES"] = "Janeiro"
base_venda_fevereiro["MES"] = "Fevereiro"

# %%
base_vendas_periodo = pd.concat([
    base_venda_dezembro, 
    base_venda_janeiro, 
    base_venda_fevereiro
], ignore_index=True)

# %%
base_vendas_periodo
# Out:
#              DATA  CODIGOCLIENTE              DESCRICAOCLIENTE  \
# 0      2025-12-01       10000964   LOGÍSTICA ESSENCIAL BEBIDAS
# 1      2025-12-01       10000964   LOGÍSTICA ESSENCIAL BEBIDAS
# 2      2025-12-01       10000964   LOGÍSTICA ESSENCIAL BEBIDAS
# 3      2025-12-01       10001683       ATACADISTA BRINDE AMIGO
# 4      2025-12-01       10004002   COMERCIAL MUNDO DAS BEBIDAS
# ...           ...            ...                           ...
# 106659        NaT       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 106660        NaT       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 106661        NaT       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 106662        NaT       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 106663        NaT       10005002  DISTRIBUIDORA ATLETA BEBIDAS
#
#         CODIGOGRUPOPRODUTO               DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 0                 90013060  Bebidas Prontas para Consumo (RTD)       10003635
# 1                 90013060  Bebidas Prontas para Consumo (RTD)       10005769
# 2                 90013172           Bebidas Mistas Alcoólicas       10015857
# 3                 90013060  Bebidas Prontas para Consumo (RTD)       10005769
# 4                 90013172           Bebidas Mistas Alcoólicas       10015849
# ...                    ...                                 ...            ...
# 106659            91503405     Energéticos de Alta Performance       10023656
# 106660            91503409             Bebidas Prontas Geladas       10021534
# 106661            91503409             Bebidas Prontas Geladas       10021535
# 106662            91503409             Bebidas Prontas Geladas       10021536
# 106663            91503409             Bebidas Prontas Geladas       10021537
#
#                                    NOMEPRODUTO  TIPOFATURAMENTO  \
# 0                     Gin Tônica em Lata 269ml                1
# 1             Pack 4 Unidades Gin Tônica 269ml                1
# 2                      Drink Misto Peach 269ml                1
# 3             Pack 4 Unidades Gin Tônica 269ml                1
# 4                  Drink Misto Blueberry 330ml                3
# ...                                        ...              ...
# 106659  Shot Energético Ultra-Concentrado 60ml                1
# 106660                Hard Seltzer Limão 310ml                1
# 106661                Hard Seltzer Amora 310ml                1
# 106662            Hard Seltzer Tangerina 310ml                1
# 106663              Hard Seltzer Abacaxi 310ml                1
#
#        DESCRICAOTIPOFATURAMENTO  VOLUME  VALORLIQUIDO        MES DATAEMISSAO
# 0                         VENDA    1315       7311.40   Dezembro         NaT
# 1                         VENDA     730       4015.00   Dezembro         NaT
# 2                         VENDA    2000      28440.00   Dezembro         NaT
# 3                         VENDA      26        377.26   Dezembro         NaT
# 4                   BONIFICAÇÃO      15         55.05   Dezembro         NaT
# ...                         ...     ...           ...        ...         ...
# 106659                    VENDA       4       1228.52  Fevereiro  2026-02-28
# 106660                    VENDA       9       1480.32  Fevereiro  2026-02-28
# 106661                    VENDA       9       1553.94  Fevereiro  2026-02-28
# 106662                    VENDA      10       1845.10  Fevereiro  2026-02-28
# 106663                    VENDA       1         88.88  Fevereiro  2026-02-28
#
# [106664 rows x 13 columns]

# %%
base_vendas_periodo.shape
# Out:
# (106664, 13)

# %% [markdown]
# ## 5. Padrozinando os campos antes de concatenar

# %%
base_venda_dezembro = base_venda_dezembro.rename(columns={
    "DATA": "DATAEMISSAO"
})

# %%
base_vendas_periodo = pd.concat([
    base_venda_dezembro, 
    base_venda_janeiro, 
    base_venda_fevereiro
], ignore_index=True)

# %% [markdown]
# ## 6. Verificando o resultado

# %%
base_vendas_periodo
# Out:
#        DATAEMISSAO  CODIGOCLIENTE              DESCRICAOCLIENTE  \
# 0       2025-12-01       10000964   LOGÍSTICA ESSENCIAL BEBIDAS
# 1       2025-12-01       10000964   LOGÍSTICA ESSENCIAL BEBIDAS
# 2       2025-12-01       10000964   LOGÍSTICA ESSENCIAL BEBIDAS
# 3       2025-12-01       10001683       ATACADISTA BRINDE AMIGO
# 4       2025-12-01       10004002   COMERCIAL MUNDO DAS BEBIDAS
# ...            ...            ...                           ...
# 106659  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 106660  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 106661  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 106662  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 106663  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
#
#         CODIGOGRUPOPRODUTO               DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 0                 90013060  Bebidas Prontas para Consumo (RTD)       10003635
# 1                 90013060  Bebidas Prontas para Consumo (RTD)       10005769
# 2                 90013172           Bebidas Mistas Alcoólicas       10015857
# 3                 90013060  Bebidas Prontas para Consumo (RTD)       10005769
# 4                 90013172           Bebidas Mistas Alcoólicas       10015849
# ...                    ...                                 ...            ...
# 106659            91503405     Energéticos de Alta Performance       10023656
# 106660            91503409             Bebidas Prontas Geladas       10021534
# 106661            91503409             Bebidas Prontas Geladas       10021535
# 106662            91503409             Bebidas Prontas Geladas       10021536
# 106663            91503409             Bebidas Prontas Geladas       10021537
#
#                                    NOMEPRODUTO  TIPOFATURAMENTO  \
# 0                     Gin Tônica em Lata 269ml                1
# 1             Pack 4 Unidades Gin Tônica 269ml                1
# 2                      Drink Misto Peach 269ml                1
# 3             Pack 4 Unidades Gin Tônica 269ml                1
# 4                  Drink Misto Blueberry 330ml                3
# ...                                        ...              ...
# 106659  Shot Energético Ultra-Concentrado 60ml                1
# 106660                Hard Seltzer Limão 310ml                1
# 106661                Hard Seltzer Amora 310ml                1
# 106662            Hard Seltzer Tangerina 310ml                1
# 106663              Hard Seltzer Abacaxi 310ml                1
#
#        DESCRICAOTIPOFATURAMENTO  VOLUME  VALORLIQUIDO        MES
# 0                         VENDA    1315       7311.40   Dezembro
# 1                         VENDA     730       4015.00   Dezembro
# 2                         VENDA    2000      28440.00   Dezembro
# 3                         VENDA      26        377.26   Dezembro
# 4                   BONIFICAÇÃO      15         55.05   Dezembro
# ...                         ...     ...           ...        ...
# 106659                    VENDA       4       1228.52  Fevereiro
# 106660                    VENDA       9       1480.32  Fevereiro
# 106661                    VENDA       9       1553.94  Fevereiro
# 106662                    VENDA      10       1845.10  Fevereiro
# 106663                    VENDA       1         88.88  Fevereiro
#
# [106664 rows x 12 columns]

# %%
base_vendas_periodo.shape
# Out:
# (106664, 12)

# %% [markdown]
# ## 7. Boas práticas
# - Garantir mesmas colunas
# - Criar coluna de rastreabilidade
# - Usar ignore_index=True
# - Validar dados após concat
# - Evitar concat em loops

# %% [markdown]
# ## 8. Pivot
#
# Agora vamos transformar a base consolidada em uma tabela analítica, facilitando a leitura dos dados.

# %% [markdown]
# ### Pivot por Mês
#
# Quanto foi faturado em cada mês?

# %%
pivot_mes = base_vendas_periodo.pivot_table(
    values="VALORLIQUIDO",
    index="MES",
    aggfunc="sum"
)

display(pivot_mes)
# Out:
#             VALORLIQUIDO
# MES
# Dezembro  349,553,210.03
# Fevereiro 127,422,295.10
# Janeiro   409,820,546.79

# %% [markdown]
# ### Por Mês e Tipo Faturamento
#
# Como o faturamento se distribui por tipo?

# %%
pivot_faturamento = base_vendas_periodo.pivot_table(
    values="VALORLIQUIDO",
    index="MES",
    columns="TIPOFATURAMENTO",
    aggfunc="sum",
    fill_value=0
)

pivot_faturamento
# Out:
# TIPOFATURAMENTO             1             2            3             13  \
# MES
# Dezembro        341,988,461.42 -1,254,101.19   130,184.58  8,703,998.45
# Fevereiro       103,395,853.13   -708,379.74 1,877,937.68 22,748,451.17
# Janeiro         401,256,922.63 -1,398,739.23   154,337.58  9,826,964.93
#
# TIPOFATURAMENTO         14
# MES
# Dezembro        -15,333.23
# Fevereiro       108,432.86
# Janeiro         -18,939.12

# %% [markdown]
# ### Faturamento por familia de produto e mês
#
# Como o faturamento se distribui por tipo?

# %%
pivot_grupo = base_vendas_periodo.pivot_table(
    values="VALORLIQUIDO",
    index="DESCRICAOGRUPOPRODUTO",
    columns="MES",
    aggfunc="sum",
    fill_value=0
)

pivot_grupo
# Out:
# MES                                        Dezembro     Fevereiro  \
# DESCRICAOGRUPOPRODUTO
# Base para Bebidas Alcoólicas              39,473.53      1,963.05
# Bebidas Energéticas Funcionais        25,910,203.13  4,040,350.56
# Bebidas Energéticas Premium           22,141,232.01  4,853,774.76
# Bebidas Funcionais Naturais               93,083.08      2,850.95
# Bebidas Funcionais Vitaminadas        15,397,990.26  4,805,289.85
# Bebidas Gasosas Saborizadas           22,500,259.54  2,241,998.95
# Bebidas Ice e Cooler                   2,909,284.12  2,124,308.88
# Bebidas Mistas Alcoólicas             82,400,597.39 60,145,298.54
# Bebidas Nutricionais                     109,241.51        673.77
# Bebidas Prontas Geladas               17,029,031.04  1,842,549.62
# Bebidas Prontas para Consumo (RTD)    34,001,361.71  4,374,827.90
# Bebidas Relaxantes e Digestivas          163,093.36      1,453.28
# Categoria de Bebidas Diversas          1,041,570.32      7,592.89
# Cervejas Artesanais Lupuladas         11,743,176.02  4,241,202.22
# Cervejas Artesanais Premium            6,176,599.66  4,917,591.71
# Cervejas Comerciais                      182,548.34      2,801.50
# Cervejas Especiais de Produção            83,897.18      1,457.34
# Cervejas Especiais de Trigo            9,433,773.11    718,797.65
# Cervejas Industriais                     161,950.43      5,899.41
# Cervejas Industriais Premium              96,525.85      1,711.39
# Cervejas Lager Tradicionais            5,993,502.77  1,910,719.60
# Cervejas Premium de Mercado                8,113.40        318.00
# Cervejas Puro Malte                    8,376,769.13 13,800,420.58
# Cervejas Regionais                     5,554,505.24  1,377,180.01
# Cervejas de Grande Produção              100,012.61      2,261.56
# Controle de Qualidade de Bebidas       1,750,496.02    680,409.65
# Destilados Clássicos                   3,437,853.88    650,224.26
# Destilados Envelhecidos                1,953,698.60    254,186.13
# Destilados Especiais                   3,575,813.70    652,124.04
# Destilados Premium                     6,570,165.99  2,659,529.01
# Destilados Ultra Premium                       0.00        161.02
# Destilados de Alta Graduação              67,497.72      7,428.90
# Energéticos de Alta Performance        3,379,205.40    766,463.54
# Equipamentos para Produção de Bebidas    852,703.63     21,049.61
# Espumantes e Vinhos Finos                 13,134.68      2,164.77
# Insumos para Produção de Bebidas       5,793,962.31  2,077,461.06
# Laboratório de Qualidade de Bebidas       95,296.84     18,038.16
# Licores e Destilados Aromáticos            9,434.88         52.92
# Matéria-prima para Bebidas               114,566.25     14,071.45
# Produção de Bebidas em Escala            141,088.23      1,854.53
# Produção de Bebidas em Grande Escala   2,298,354.74    582,369.34
# Refrigerantes Premium                     11,395.44        162.20
# Refrigerantes Sabor Cola              11,295,098.71    568,012.38
# Refrigerantes Sabor Frutas             3,522,442.84    259,390.21
# Refrigerantes Tradicionais             1,379,910.65     78,709.76
# Sucos Naturais Premium                20,198,977.41  3,366,567.61
# Vinhos Tintos Importados              11,316,748.22  3,331,726.47
# Vinhos e Espumantes                      127,569.15      6,844.11
#
# MES                                         Janeiro
# DESCRICAOGRUPOPRODUTO
# Base para Bebidas Alcoólicas             125,592.09
# Bebidas Energéticas Funcionais        30,730,991.68
# Bebidas Energéticas Premium           25,901,541.52
# Bebidas Funcionais Naturais               70,964.32
# Bebidas Funcionais Vitaminadas        17,792,760.73
# Bebidas Gasosas Saborizadas           27,390,970.06
# Bebidas Ice e Cooler                   2,878,772.79
# Bebidas Mistas Alcoólicas             96,157,237.74
# Bebidas Nutricionais                      95,555.22
# Bebidas Prontas Geladas               20,288,164.96
# Bebidas Prontas para Consumo (RTD)    39,868,158.70
# Bebidas Relaxantes e Digestivas          105,779.22
# Categoria de Bebidas Diversas          1,102,299.67
# Cervejas Artesanais Lupuladas         13,971,819.31
# Cervejas Artesanais Premium            7,520,004.45
# Cervejas Comerciais                      126,637.54
# Cervejas Especiais de Produção           102,772.99
# Cervejas Especiais de Trigo           10,270,918.02
# Cervejas Industriais                     188,085.66
# Cervejas Industriais Premium             132,422.67
# Cervejas Lager Tradicionais            6,690,827.81
# Cervejas Premium de Mercado               16,224.00
# Cervejas Puro Malte                    9,442,884.25
# Cervejas Regionais                     6,271,697.34
# Cervejas de Grande Produção              116,898.42
# Controle de Qualidade de Bebidas       1,940,460.12
# Destilados Clássicos                   3,828,082.42
# Destilados Envelhecidos                2,474,134.14
# Destilados Especiais                   4,194,819.40
# Destilados Premium                     7,971,442.02
# Destilados Ultra Premium                  10,307.95
# Destilados de Alta Graduação              63,617.38
# Energéticos de Alta Performance        4,263,432.86
# Equipamentos para Produção de Bebidas    868,051.05
# Espumantes e Vinhos Finos                 34,370.02
# Insumos para Produção de Bebidas       7,324,812.76
# Laboratório de Qualidade de Bebidas       25,320.55
# Licores e Destilados Aromáticos           32,472.84
# Matéria-prima para Bebidas                69,390.13
# Produção de Bebidas em Escala            137,806.11
# Produção de Bebidas em Grande Escala   2,600,119.36
# Refrigerantes Premium                     48,701.19
# Refrigerantes Sabor Cola              13,387,408.72
# Refrigerantes Sabor Frutas             4,242,495.46
# Refrigerantes Tradicionais             1,115,623.30
# Sucos Naturais Premium                23,637,785.49
# Vinhos Tintos Importados              14,075,851.30
# Vinhos e Espumantes                      114,061.06

# %% [markdown]
# ### Sem ordenação, a tabela fica inútil.

# %%
pivot_grupo = pivot_grupo.sort_values(
    by="Fevereiro",
    ascending=False
)

pivot_grupo
# Out:
# MES                                        Dezembro     Fevereiro  \
# DESCRICAOGRUPOPRODUTO
# Bebidas Mistas Alcoólicas             82,400,597.39 60,145,298.54
# Cervejas Puro Malte                    8,376,769.13 13,800,420.58
# Cervejas Artesanais Premium            6,176,599.66  4,917,591.71
# Bebidas Energéticas Premium           22,141,232.01  4,853,774.76
# Bebidas Funcionais Vitaminadas        15,397,990.26  4,805,289.85
# Bebidas Prontas para Consumo (RTD)    34,001,361.71  4,374,827.90
# Cervejas Artesanais Lupuladas         11,743,176.02  4,241,202.22
# Bebidas Energéticas Funcionais        25,910,203.13  4,040,350.56
# Sucos Naturais Premium                20,198,977.41  3,366,567.61
# Vinhos Tintos Importados              11,316,748.22  3,331,726.47
# Destilados Premium                     6,570,165.99  2,659,529.01
# Bebidas Gasosas Saborizadas           22,500,259.54  2,241,998.95
# Bebidas Ice e Cooler                   2,909,284.12  2,124,308.88
# Insumos para Produção de Bebidas       5,793,962.31  2,077,461.06
# Cervejas Lager Tradicionais            5,993,502.77  1,910,719.60
# Bebidas Prontas Geladas               17,029,031.04  1,842,549.62
# Cervejas Regionais                     5,554,505.24  1,377,180.01
# Energéticos de Alta Performance        3,379,205.40    766,463.54
# Cervejas Especiais de Trigo            9,433,773.11    718,797.65
# Controle de Qualidade de Bebidas       1,750,496.02    680,409.65
# Destilados Especiais                   3,575,813.70    652,124.04
# Destilados Clássicos                   3,437,853.88    650,224.26
# Produção de Bebidas em Grande Escala   2,298,354.74    582,369.34
# Refrigerantes Sabor Cola              11,295,098.71    568,012.38
# Refrigerantes Sabor Frutas             3,522,442.84    259,390.21
# Destilados Envelhecidos                1,953,698.60    254,186.13
# Refrigerantes Tradicionais             1,379,910.65     78,709.76
# Equipamentos para Produção de Bebidas    852,703.63     21,049.61
# Laboratório de Qualidade de Bebidas       95,296.84     18,038.16
# Matéria-prima para Bebidas               114,566.25     14,071.45
# Categoria de Bebidas Diversas          1,041,570.32      7,592.89
# Destilados de Alta Graduação              67,497.72      7,428.90
# Vinhos e Espumantes                      127,569.15      6,844.11
# Cervejas Industriais                     161,950.43      5,899.41
# Bebidas Funcionais Naturais               93,083.08      2,850.95
# Cervejas Comerciais                      182,548.34      2,801.50
# Cervejas de Grande Produção              100,012.61      2,261.56
# Espumantes e Vinhos Finos                 13,134.68      2,164.77
# Base para Bebidas Alcoólicas              39,473.53      1,963.05
# Produção de Bebidas em Escala            141,088.23      1,854.53
# Cervejas Industriais Premium              96,525.85      1,711.39
# Cervejas Especiais de Produção            83,897.18      1,457.34
# Bebidas Relaxantes e Digestivas          163,093.36      1,453.28
# Bebidas Nutricionais                     109,241.51        673.77
# Cervejas Premium de Mercado                8,113.40        318.00
# Refrigerantes Premium                     11,395.44        162.20
# Destilados Ultra Premium                       0.00        161.02
# Licores e Destilados Aromáticos            9,434.88         52.92
#
# MES                                         Janeiro
# DESCRICAOGRUPOPRODUTO
# Bebidas Mistas Alcoólicas             96,157,237.74
# Cervejas Puro Malte                    9,442,884.25
# Cervejas Artesanais Premium            7,520,004.45
# Bebidas Energéticas Premium           25,901,541.52
# Bebidas Funcionais Vitaminadas        17,792,760.73
# Bebidas Prontas para Consumo (RTD)    39,868,158.70
# Cervejas Artesanais Lupuladas         13,971,819.31
# Bebidas Energéticas Funcionais        30,730,991.68
# Sucos Naturais Premium                23,637,785.49
# Vinhos Tintos Importados              14,075,851.30
# Destilados Premium                     7,971,442.02
# Bebidas Gasosas Saborizadas           27,390,970.06
# Bebidas Ice e Cooler                   2,878,772.79
# Insumos para Produção de Bebidas       7,324,812.76
# Cervejas Lager Tradicionais            6,690,827.81
# Bebidas Prontas Geladas               20,288,164.96
# Cervejas Regionais                     6,271,697.34
# Energéticos de Alta Performance        4,263,432.86
# Cervejas Especiais de Trigo           10,270,918.02
# Controle de Qualidade de Bebidas       1,940,460.12
# Destilados Especiais                   4,194,819.40
# Destilados Clássicos                   3,828,082.42
# Produção de Bebidas em Grande Escala   2,600,119.36
# Refrigerantes Sabor Cola              13,387,408.72
# Refrigerantes Sabor Frutas             4,242,495.46
# Destilados Envelhecidos                2,474,134.14
# Refrigerantes Tradicionais             1,115,623.30
# Equipamentos para Produção de Bebidas    868,051.05
# Laboratório de Qualidade de Bebidas       25,320.55
# Matéria-prima para Bebidas                69,390.13
# Categoria de Bebidas Diversas          1,102,299.67
# Destilados de Alta Graduação              63,617.38
# Vinhos e Espumantes                      114,061.06
# Cervejas Industriais                     188,085.66
# Bebidas Funcionais Naturais               70,964.32
# Cervejas Comerciais                      126,637.54
# Cervejas de Grande Produção              116,898.42
# Espumantes e Vinhos Finos                 34,370.02
# Base para Bebidas Alcoólicas             125,592.09
# Produção de Bebidas em Escala            137,806.11
# Cervejas Industriais Premium             132,422.67
# Cervejas Especiais de Produção           102,772.99
# Bebidas Relaxantes e Digestivas          105,779.22
# Bebidas Nutricionais                      95,555.22
# Cervejas Premium de Mercado               16,224.00
# Refrigerantes Premium                     48,701.19
# Destilados Ultra Premium                  10,307.95
# Licores e Destilados Aromáticos           32,472.84

# %% [markdown]
# ### Múltiplas métricas

# %%
pivot_multi = base_vendas_periodo.pivot_table(
    values=["VALORLIQUIDO", "VOLUME"],
    index="MES",
    aggfunc="sum"
)

pivot_multi
# Out:
#             VALORLIQUIDO    VOLUME
# MES
# Dezembro  349,553,210.03  27967966
# Fevereiro 127,422,295.10   1267688
# Janeiro   409,820,546.79  32713671
