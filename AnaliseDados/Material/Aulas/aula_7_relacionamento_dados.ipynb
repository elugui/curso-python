# %% [markdown]
# # Aula 07 – Relacionamento de Dados
#
# ## Objetivo
# Relacionar base de vendas (fato) com dimensões de cliente e produto usando dados reais.

# %% [markdown]
# ## 1. Importando bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ## 2. Carregando os dados

# %%
caminho_arquivo_base_venda = r"C:\Users\Joao.Maria\Documents\curso-python_joao_pedro\Base\Captura_venda_marco.json"
caminho_configuracao_produto = r"C:\Users\Joao.Maria\Documents\curso-python_joao_pedro\Base\Configuração Produto.xlsx"
caminho_configuracao_cliente = r"C:\Users\Joao.Maria\Documents\curso-python_joao_pedro\Base\Configuração Cliente.xlsx"

# %%
base_venda = pd.read_json(caminho_arquivo_base_venda, orient="records")
configuracao_produto = pd.read_excel(caminho_configuracao_produto, sheet_name="Produto")
configuracao_cliente = pd.read_excel(caminho_configuracao_cliente, sheet_name="Cliente")

# %% [markdown]
# ## 3. Visualizando as bases

# %%
base_venda.head()
# Out:
#                DATAEMISSAO  CODIGOCLIENTE  CODIGOPRODUTO  TIPOFATURAMENTO  \
# 0  2026-03-01T00:00:00.000       10004221       10023656                1
# 1  2026-03-01T00:00:00.000       10004238       10001164                1
# 2  2026-03-01T00:00:00.000       10004005       10003635                1
# 3  2026-03-01T00:00:00.000       10004221       10026840                1
# 4  2026-03-01T00:00:00.000       10004002       10022282                1
#
#   DESCRICAOTIPOFATURAMENTO  VOLUME  VALORLIQUIDO
# 0                    VENDA    1635      19440.15
# 1                    VENDA    1852      36743.68
# 2                    VENDA    1684      10272.40
# 3                    VENDA      69       1255.80
# 4                    VENDA     845      16773.25

# %%
configuracao_produto.head()
# Out:
#    CODIGOFAMILIA DESCRICAOFAMILIA  CODIGOGRUPOPRODUTO  \
# 0       80000003       Energético            91503402
# 1       80000001          Cerveja            90013201
# 2       80000007            Vinho            90013032
# 3       80000001          Cerveja            90013011
# 4       80000002     Refrigerante            90013153
#
#             DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 0  Bebidas Energéticas Funcionais       10022949
# 1     Cervejas Artesanais Premium       10001163
# 2        Vinhos Tintos Importados       10001164
# 3     Cervejas Lager Tradicionais       10001628
# 4        Refrigerantes Sabor Cola       10001864
#
#                             NOMEPRODUTO
# 0     Energético Focus Max 1L (Garrafa)
# 1    Cerveja Artesanal Alpha Gold 600ml
# 2  Vinho Tinto Cabernet Reservado 750ml
# 3   Cerveja Lager Standard 350ml (Lata)
# 4             Refri Cola Original 250ml

# %%
configuracao_cliente.head()
# Out:
#    CODIGOCLIENTE                 DESCRICAOCLIENTE                CNPJ  \
# 0       10004231  DISTRIBUIDORA REINO DAS BEBIDAS  37.582.419/0001-04
# 1       10004226     LOGÍSTICA CENTRAL DE BEBIDAS  91.604.237/0001-62
# 2       10004220              ATACADO COPO GELADO  18.773.950/0001-15
# 3       10004201    SUPRIMENTOS PREMIUM BEVERAGES  52.449.681/0001-89
# 4       10004210    CENTRAL LOGÍSTICA DAS BEBIDAS  73.601.228/0001-33
#
#    CODIGOGRUPOCLIENTE DESCRICAOGRUPOCLIENTE
# 0                   2          Distribuidor
# 1                   2          Distribuidor
# 2                   2          Distribuidor
# 3                   2          Distribuidor
# 4                   2          Distribuidor

# %% [markdown]
# ## 4. Merge com Cliente (LEFT JOIN)

# %% [markdown]
# ### Mantém todas as vendas, mesmo sem cliente correspondente.

# %%
base = pd.merge(
    base_venda, 
    configuracao_cliente, 
    on='CODIGOCLIENTE', 
    how='left'
)

base.head()
# Out:
#                DATAEMISSAO  CODIGOCLIENTE  CODIGOPRODUTO  TIPOFATURAMENTO  \
# 0  2026-03-01T00:00:00.000       10004221       10023656                1
# 1  2026-03-01T00:00:00.000       10004238       10001164                1
# 2  2026-03-01T00:00:00.000       10004005       10003635                1
# 3  2026-03-01T00:00:00.000       10004221       10026840                1
# 4  2026-03-01T00:00:00.000       10004002       10022282                1
#
#   DESCRICAOTIPOFATURAMENTO  VOLUME  VALORLIQUIDO  \
# 0                    VENDA    1635      19440.15
# 1                    VENDA    1852      36743.68
# 2                    VENDA    1684      10272.40
# 3                    VENDA      69       1255.80
# 4                    VENDA     845      16773.25
#
#                   DESCRICAOCLIENTE                CNPJ  CODIGOGRUPOCLIENTE  \
# 0    DISTRIBUIDORA BRINDE & AMIGOS  68.913.227/0001-22                   2
# 1      LOGÍSTICA BEBIDAS DO BRASIL  47.318.775/0001-86                   2
# 2  DISTRIBUIDORA SABOR DAS BEBIDAS  11.908.442/0001-36                   2
# 3    DISTRIBUIDORA BRINDE & AMIGOS  68.913.227/0001-22                   2
# 4      COMERCIAL MUNDO DAS BEBIDAS  31.662.540/0001-16                   2
#
#   DESCRICAOGRUPOCLIENTE
# 0          Distribuidor
# 1          Distribuidor
# 2          Distribuidor
# 3          Distribuidor
# 4          Distribuidor

# %% [markdown]
# #### Tem como também trazer apenas os campos ao qual a gente precisa

# %%
base_cliente = pd.merge(
    base_venda, 
    configuracao_cliente[["CODIGOCLIENTE", "DESCRICAOCLIENTE"]], 
    on='CODIGOCLIENTE', 
    how='left'
)

base_cliente.head()
# Out:
#                DATAEMISSAO  CODIGOCLIENTE  CODIGOPRODUTO  TIPOFATURAMENTO  \
# 0  2026-03-01T00:00:00.000       10004221       10023656                1
# 1  2026-03-01T00:00:00.000       10004238       10001164                1
# 2  2026-03-01T00:00:00.000       10004005       10003635                1
# 3  2026-03-01T00:00:00.000       10004221       10026840                1
# 4  2026-03-01T00:00:00.000       10004002       10022282                1
#
#   DESCRICAOTIPOFATURAMENTO  VOLUME  VALORLIQUIDO  \
# 0                    VENDA    1635      19440.15
# 1                    VENDA    1852      36743.68
# 2                    VENDA    1684      10272.40
# 3                    VENDA      69       1255.80
# 4                    VENDA     845      16773.25
#
#                   DESCRICAOCLIENTE
# 0    DISTRIBUIDORA BRINDE & AMIGOS
# 1      LOGÍSTICA BEBIDAS DO BRASIL
# 2  DISTRIBUIDORA SABOR DAS BEBIDAS
# 3    DISTRIBUIDORA BRINDE & AMIGOS
# 4      COMERCIAL MUNDO DAS BEBIDAS

# %% [markdown]
# ## 5. Merge com Produto

# %%
base = pd.merge(
    base, 
    configuracao_produto[["CODIGOPRODUTO", "NOMEPRODUTO", "DESCRICAOGRUPOPRODUTO", "DESCRICAOFAMILIA"]], 
    on='CODIGOPRODUTO', 
    how='left'
)

base.head()
# Out:
#                DATAEMISSAO  CODIGOCLIENTE  CODIGOPRODUTO  TIPOFATURAMENTO  \
# 0  2026-03-01T00:00:00.000       10004221       10023656                1
# 1  2026-03-01T00:00:00.000       10004238       10001164                1
# 2  2026-03-01T00:00:00.000       10004005       10003635                1
# 3  2026-03-01T00:00:00.000       10004221       10026840                1
# 4  2026-03-01T00:00:00.000       10004002       10022282                1
#
#   DESCRICAOTIPOFATURAMENTO  VOLUME  VALORLIQUIDO  \
# 0                    VENDA    1635      19440.15
# 1                    VENDA    1852      36743.68
# 2                    VENDA    1684      10272.40
# 3                    VENDA      69       1255.80
# 4                    VENDA     845      16773.25
#
#                   DESCRICAOCLIENTE                CNPJ  CODIGOGRUPOCLIENTE  \
# 0    DISTRIBUIDORA BRINDE & AMIGOS  68.913.227/0001-22                   2
# 1      LOGÍSTICA BEBIDAS DO BRASIL  47.318.775/0001-86                   2
# 2  DISTRIBUIDORA SABOR DAS BEBIDAS  11.908.442/0001-36                   2
# 3    DISTRIBUIDORA BRINDE & AMIGOS  68.913.227/0001-22                   2
# 4      COMERCIAL MUNDO DAS BEBIDAS  31.662.540/0001-16                   2
#
#   DESCRICAOGRUPOCLIENTE                             NOMEPRODUTO  \
# 0          Distribuidor  Shot Energético Ultra-Concentrado 60ml
# 1          Distribuidor    Vinho Tinto Cabernet Reservado 750ml
# 2          Distribuidor                Gin Tônica em Lata 269ml
# 3          Distribuidor         Cerveja Session IPA Light 355ml
# 4          Distribuidor          Isotônico Uva Vitaminado 500ml
#
#                 DESCRICAOGRUPOPRODUTO DESCRICAOFAMILIA
# 0     Energéticos de Alta Performance       Energético
# 1            Vinhos Tintos Importados            Vinho
# 2  Bebidas Prontas para Consumo (RTD)              RTD
# 3       Cervejas Artesanais Lupuladas          Cerveja
# 4      Bebidas Funcionais Vitaminadas       Energético

# %% [markdown]
# ## 6. Problema real – Chaves faltantes

# %%
base.isnull().sum()
# Out:
# DATAEMISSAO                 0
# CODIGOCLIENTE               0
# CODIGOPRODUTO               0
# TIPOFATURAMENTO             0
# DESCRICAOTIPOFATURAMENTO    0
# VOLUME                      0
# VALORLIQUIDO                0
# DESCRICAOCLIENTE            0
# CNPJ                        0
# CODIGOGRUPOCLIENTE          0
# DESCRICAOGRUPOCLIENTE       0
# NOMEPRODUTO                 0
# DESCRICAOGRUPOPRODUTO       0
# DESCRICAOFAMILIA            0
# dtype: int64

# %% [markdown]
# ### Se houver valores nulos em cliente ou produto, o relacionamento falhou.

# %% [markdown]
# ## 7. Problema crítico – Duplicidade na dimensão

# %%
configuracao_cliente['CODIGOCLIENTE'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Se > 0, você vai multiplicar linhas no merge.

# %% [markdown]
# 👉 Se aumentou, você tem explosão de dados.

# %% [markdown]
# ## 8. Tipos de Ligação
#
#     how=
# * **inner** → Mantém apenas os registros que existem nas duas tabelas
# * **left** → Mantém todos os registros da tabela da esquerda e traz correspondências da direita
# * **right** → Mantém todos os registros da tabela da direita e traz correspondências da esquerda
# * **outer** → Mantém todos os registros de ambas as tabelas, combinando onde houver correspondência

# %%
clientes_faltantes = pd.merge(
    base_venda,
    configuracao_cliente[["CODIGOCLIENTE", "DESCRICAOCLIENTE"]],
    on="CODIGOCLIENTE",
    how="right"
)
# Out:
#                DATAEMISSAO  CODIGOCLIENTE  CODIGOPRODUTO  TIPOFATURAMENTO  \
# 0                      NaN       10004231            NaN              NaN
# 1  2026-03-01T00:00:00.000       10004226     10022283.0              1.0
# 2  2026-03-01T00:00:00.000       10004226     10020282.0              1.0
# 3  2026-03-01T00:00:00.000       10004226     10016993.0              1.0
# 4  2026-03-01T00:00:00.000       10004226     10003736.0              1.0
#
#   DESCRICAOTIPOFATURAMENTO  VOLUME  VALORLIQUIDO  \
# 0                      NaN     NaN           NaN
# 1                    VENDA  1017.0      16251.66
# 2                    VENDA   200.0       1810.00
# 3                    VENDA    27.0        532.44
# 4                    VENDA  1542.0      24070.62
#
#                   DESCRICAOCLIENTE
# 0  DISTRIBUIDORA REINO DAS BEBIDAS
# 1     LOGÍSTICA CENTRAL DE BEBIDAS
# 2     LOGÍSTICA CENTRAL DE BEBIDAS
# 3     LOGÍSTICA CENTRAL DE BEBIDAS
# 4     LOGÍSTICA CENTRAL DE BEBIDAS

# %% [markdown]
# ### Filtrando apenas os clientes faltantes

# %%
clientes_faltantes = clientes_faltantes[clientes_faltantes["DATAEMISSAO"].isnull()]

clientes_faltantes.head()
# Out:
#      DATAEMISSAO  CODIGOCLIENTE  CODIGOPRODUTO  TIPOFATURAMENTO  \
# 0            NaN       10004231            NaN              NaN
# 645          NaN       10004220            NaN              NaN
# 1545         NaN       10004210            NaN              NaN
# 1546         NaN       10004003            NaN              NaN
# 2592         NaN       10004212            NaN              NaN
#
#      DESCRICAOTIPOFATURAMENTO  VOLUME  VALORLIQUIDO  \
# 0                         NaN     NaN           NaN
# 645                       NaN     NaN           NaN
# 1545                      NaN     NaN           NaN
# 1546                      NaN     NaN           NaN
# 2592                      NaN     NaN           NaN
#
#                       DESCRICAOCLIENTE
# 0      DISTRIBUIDORA REINO DAS BEBIDAS
# 645                ATACADO COPO GELADO
# 1545     CENTRAL LOGÍSTICA DAS BEBIDAS
# 1546    REDE BRINDE FELIZ DISTRIBUIÇÃO
# 2592  DISTRIBUIDORA PORTAL DAS BEBIDAS

# %% [markdown]
# ### Identificando os valores nulos de ambas as bases
#
# #### indicator=True cria uma coluna:
#
# * left_only -> só existe em vendas
# * right_only -> só existe em clientes
# * both -> existe nos dois

# %%
comparacao = pd.merge(
    base_venda,
    configuracao_cliente[["CODIGOCLIENTE", "DESCRICAOCLIENTE"]],
    on="CODIGOCLIENTE",
    how="outer",
    indicator=True
)

comparacao.head(25)
# Out:
#                 DATAEMISSAO  CODIGOCLIENTE  CODIGOPRODUTO  TIPOFATURAMENTO  \
# 0                       NaN       10000449            NaN              NaN
# 1                       NaN       10000964            NaN              NaN
# 2                       NaN       10001683            NaN              NaN
# 3                       NaN       10004001            NaN              NaN
# 4   2026-03-01T00:00:00.000       10004002     10022282.0              1.0
# 5   2026-03-01T00:00:00.000       10004002     10015849.0              1.0
# 6   2026-03-01T00:00:00.000       10004002     10021534.0              1.0
# 7   2026-03-01T00:00:00.000       10004002     10015850.0              1.0
# 8   2026-03-01T00:00:00.000       10004002     10002818.0              1.0
# 9   2026-03-01T00:00:00.000       10004002     10022637.0              1.0
# 10  2026-03-01T00:00:00.000       10004002     10022283.0              1.0
# 11  2026-03-01T00:00:00.000       10004002     10022283.0              1.0
# 12  2026-03-01T00:00:00.000       10004002     10015849.0              3.0
# 13  2026-03-01T00:00:00.000       10004002     10022954.0              1.0
# 14  2026-03-01T00:00:00.000       10004002     10015850.0              1.0
# 15  2026-03-01T00:00:00.000       10004002     10001864.0              3.0
# 16  2026-03-01T00:00:00.000       10004002     10008336.0              1.0
# 17  2026-03-01T00:00:00.000       10004002     10022282.0              1.0
# 18  2026-03-01T00:00:00.000       10004002     10003698.0              1.0
# 19  2026-03-01T00:00:00.000       10004002     10022281.0              1.0
# 20  2026-03-01T00:00:00.000       10004002     10021924.0              1.0
# 21  2026-03-01T00:00:00.000       10004002     10022636.0              1.0
# 22  2026-03-01T00:00:00.000       10004002     10001163.0              1.0
# 23  2026-03-01T00:00:00.000       10004002     10020282.0              1.0
# 24  2026-03-01T00:00:00.000       10004002     10003698.0              1.0
#
#    DESCRICAOTIPOFATURAMENTO  VOLUME  VALORLIQUIDO  \
# 0                       NaN     NaN           NaN
# 1                       NaN     NaN           NaN
# 2                       NaN     NaN           NaN
# 3                       NaN     NaN           NaN
# 4                     VENDA   845.0      16773.25
# 5                     VENDA  1389.0      14959.53
# 6                     VENDA   693.0      11725.56
# 7                     VENDA    39.0        417.69
# 8                     VENDA  1793.0      34766.27
# 9                     VENDA  1481.0      22570.44
# 10                    VENDA   153.0        921.06
# 11                    VENDA  1484.0      23788.52
# 12              BONIFICAÇÃO    42.0        193.62
# 13                    VENDA     9.0        100.53
# 14                    VENDA  1422.0      28198.26
# 15              BONIFICAÇÃO    34.0        156.40
# 16                    VENDA  1581.0      15082.74
# 17                    VENDA   186.0       2099.94
# 18                    VENDA  1764.0      10001.88
# 19                    VENDA   174.0       1889.64
# 20                    VENDA   712.0       5461.04
# 21                    VENDA   844.0       7207.76
# 22                    VENDA   102.0       1116.90
# 23                    VENDA   679.0       4121.53
# 24                    VENDA   415.0       8109.10
#
#                DESCRICAOCLIENTE      _merge
# 0          ATACADO BRINDE & CIA  right_only
# 1   LOGÍSTICA ESSENCIAL BEBIDAS  right_only
# 2       ATACADISTA BRINDE AMIGO  right_only
# 3      LOGÍSTICA GARRAFAS & LOG  right_only
# 4   COMERCIAL MUNDO DAS BEBIDAS        both
# 5   COMERCIAL MUNDO DAS BEBIDAS        both
# 6   COMERCIAL MUNDO DAS BEBIDAS        both
# 7   COMERCIAL MUNDO DAS BEBIDAS        both
# 8   COMERCIAL MUNDO DAS BEBIDAS        both
# 9   COMERCIAL MUNDO DAS BEBIDAS        both
# 10  COMERCIAL MUNDO DAS BEBIDAS        both
# 11  COMERCIAL MUNDO DAS BEBIDAS        both
# 12  COMERCIAL MUNDO DAS BEBIDAS        both
# 13  COMERCIAL MUNDO DAS BEBIDAS        both
# 14  COMERCIAL MUNDO DAS BEBIDAS        both
# 15  COMERCIAL MUNDO DAS BEBIDAS        both
# 16  COMERCIAL MUNDO DAS BEBIDAS        both
# 17  COMERCIAL MUNDO DAS BEBIDAS        both
# 18  COMERCIAL MUNDO DAS BEBIDAS        both
# 19  COMERCIAL MUNDO DAS BEBIDAS        both
# 20  COMERCIAL MUNDO DAS BEBIDAS        both
# 21  COMERCIAL MUNDO DAS BEBIDAS        both
# 22  COMERCIAL MUNDO DAS BEBIDAS        both
# 23  COMERCIAL MUNDO DAS BEBIDAS        both
# 24  COMERCIAL MUNDO DAS BEBIDAS        both
