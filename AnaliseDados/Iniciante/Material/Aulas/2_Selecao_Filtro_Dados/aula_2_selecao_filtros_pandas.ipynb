# %% [markdown]
# # Aula 10 – Seleção e Filtros de Dados
#
# ## Objetivo da aula
#
# Nesta aula vamos aprender como selecionar colunas, filtrar linhas e organizar dados no **Pandas**.
#
# Você irá aprender:
#
# - Seleção de colunas
# - Uso de **loc** e **iloc**
# - Filtros booleanos
# - Uso de **query()**
# - Uso de **unique()**
# - Uso de **value_counts()**
# - Uso de **sort_values()**

# %% [markdown]
# # 1. Importando o Pandas
#
# Vamos começar importando a biblioteca **Pandas**.

# %%
import pandas as pd

# %% [markdown]
# # 2. Lendo a base de dados
#
# Vamos carregar a base que será usada nos exemplos.

# %%
arquivo = r"C:\Users\Joao.Maria\Documents\curso-python_joao_pedro\Base\Base_analitica_vendas.xlsx"

base_vendas = pd.read_excel(arquivo, sheet_name="Base")

# %% [markdown]
# # 3. Seleção de colunas
#
# Podemos selecionar uma ou mais colunas da base.
#
# ### Selecionando uma coluna

# %%
base_vendas["DESCRICAOCLIENTE"]
# Out:
# 0                ATACADO BRINDE & CIA
# 1                ATACADO BRINDE & CIA
# 2                ATACADO BRINDE & CIA
# 3                ATACADO BRINDE & CIA
# 4                ATACADO BRINDE & CIA
#                      ...
# 43117    DISTRIBUIDORA ATLETA BEBIDAS
# 43118    DISTRIBUIDORA ATLETA BEBIDAS
# 43119    DISTRIBUIDORA ATLETA BEBIDAS
# 43120    DISTRIBUIDORA ATLETA BEBIDAS
# 43121    DISTRIBUIDORA ATLETA BEBIDAS
# Name: DESCRICAOCLIENTE, Length: 43122, dtype: str

# %% [markdown]
# ### Selecionando várias colunas

# %%
base_vendas[["DESCRICAOCLIENTE", "NOMEPRODUTO", "VALORLIQUIDO"]]
# Out:
#                    DESCRICAOCLIENTE                             NOMEPRODUTO  \
# 0              ATACADO BRINDE & CIA          Isotônico Uva Vitaminado 500ml
# 1              ATACADO BRINDE & CIA     Cerveja Lager Standard 350ml (Lata)
# 2              ATACADO BRINDE & CIA          Suco de Laranja Integral 500ml
# 3              ATACADO BRINDE & CIA                Néctar de Uva Premium 1L
# 4              ATACADO BRINDE & CIA     Lúpulo em Pellet para Brassagem 5kg
# ...                             ...                                     ...
# 43117  DISTRIBUIDORA ATLETA BEBIDAS  Shot Energético Ultra-Concentrado 60ml
# 43118  DISTRIBUIDORA ATLETA BEBIDAS                Hard Seltzer Limão 310ml
# 43119  DISTRIBUIDORA ATLETA BEBIDAS                Hard Seltzer Amora 310ml
# 43120  DISTRIBUIDORA ATLETA BEBIDAS            Hard Seltzer Tangerina 310ml
# 43121  DISTRIBUIDORA ATLETA BEBIDAS              Hard Seltzer Abacaxi 310ml
#
#        VALORLIQUIDO
# 0            472.41
# ...

# %% [markdown]
# # 4. Seleção com loc
#
# O **loc** seleciona dados usando **rótulos**: nomes de linhas e colunas.
#
# ### Selecionando linhas e colunas específicas

# %%
base_vendas.loc[0:4, ["DESCRICAOCLIENTE", "NOMEPRODUTO", "VALORLIQUIDO"]]
# Out:
#        DESCRICAOCLIENTE                          NOMEPRODUTO  VALORLIQUIDO
# 0  ATACADO BRINDE & CIA       Isotônico Uva Vitaminado 500ml        472.41
# 1  ATACADO BRINDE & CIA  Cerveja Lager Standard 350ml (Lata)       1973.87
# 2  ATACADO BRINDE & CIA       Suco de Laranja Integral 500ml        444.46
# 3  ATACADO BRINDE & CIA             Néctar de Uva Premium 1L        397.90
# 4  ATACADO BRINDE & CIA  Lúpulo em Pellet para Brassagem 5kg       1304.07

# %% [markdown]
# ### Selecionando todas as linhas de uma coluna

# %%
base_vendas.loc[:, ["DESCRICAOCLIENTE", "VALORLIQUIDO"]]
# Out:
#                    DESCRICAOCLIENTE  VALORLIQUIDO
# 0              ATACADO BRINDE & CIA        472.41
# 1              ATACADO BRINDE & CIA       1973.87
# 2              ATACADO BRINDE & CIA        444.46
# 3              ATACADO BRINDE & CIA        397.90
# 4              ATACADO BRINDE & CIA       1304.07
# ...                             ...           ...
# 43117  DISTRIBUIDORA ATLETA BEBIDAS       1228.52
# 43118  DISTRIBUIDORA ATLETA BEBIDAS       1480.32
# 43119  DISTRIBUIDORA ATLETA BEBIDAS       1553.94
# 43120  DISTRIBUIDORA ATLETA BEBIDAS       1845.10
# 43121  DISTRIBUIDORA ATLETA BEBIDAS         88.88
#
# [43122 rows x 2 columns]

# %% [markdown]
# # 5. Seleção com iloc
#
# O **iloc** seleciona dados pela **posição numérica**.
#
# ### Selecionando linhas e colunas por posição

# %%
base_vendas.iloc[0:5, 0:4]
# Out:
#   DATAEMISSAO  CODIGOCLIENTE      DESCRICAOCLIENTE  CODIGOGRUPOPRODUTO
# 0  2026-02-01       10000449  ATACADO BRINDE & CIA            90013006
# 1  2026-02-01       10000449  ATACADO BRINDE & CIA            90013011
# 2  2026-02-01       10000449  ATACADO BRINDE & CIA            90013014
# 3  2026-02-01       10000449  ATACADO BRINDE & CIA            90013014
# 4  2026-02-01       10000449  ATACADO BRINDE & CIA            90013022

# %% [markdown]
# ### Selecionando apenas algumas colunas por posição

# %%
base_vendas.iloc[:, [2, 6, 10]]
# Out:
#                    DESCRICAOCLIENTE                             NOMEPRODUTO  \
# 0              ATACADO BRINDE & CIA          Isotônico Uva Vitaminado 500ml
# 1              ATACADO BRINDE & CIA     Cerveja Lager Standard 350ml (Lata)
# 2              ATACADO BRINDE & CIA          Suco de Laranja Integral 500ml
# 3              ATACADO BRINDE & CIA                Néctar de Uva Premium 1L
# 4              ATACADO BRINDE & CIA     Lúpulo em Pellet para Brassagem 5kg
# ...                             ...                                     ...
# 43117  DISTRIBUIDORA ATLETA BEBIDAS  Shot Energético Ultra-Concentrado 60ml
# 43118  DISTRIBUIDORA ATLETA BEBIDAS                Hard Seltzer Limão 310ml
# 43119  DISTRIBUIDORA ATLETA BEBIDAS                Hard Seltzer Amora 310ml
# 43120  DISTRIBUIDORA ATLETA BEBIDAS            Hard Seltzer Tangerina 310ml
# 43121  DISTRIBUIDORA ATLETA BEBIDAS              Hard Seltzer Abacaxi 310ml
#
#        VALORLIQUIDO
# 0            472.41
# ...

# %% [markdown]
# # 6. Filtros booleanos
#
# Filtros booleanos servem para retornar apenas as linhas que atendem a uma condição.
#
# ### Filtrando valores maiores que 1000

# %%
base_vendas[base_vendas["VALORLIQUIDO"] > 1000]
# Out:
#       DATAEMISSAO  CODIGOCLIENTE              DESCRICAOCLIENTE  \
# 1      2026-02-01       10000449          ATACADO BRINDE & CIA
# 4      2026-02-01       10000449          ATACADO BRINDE & CIA
# 5      2026-02-01       10000449          ATACADO BRINDE & CIA
# 6      2026-02-01       10000449          ATACADO BRINDE & CIA
# 8      2026-02-01       10000449          ATACADO BRINDE & CIA
# ...           ...            ...                           ...
# 43116  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43117  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43118  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43119  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43120  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
#
#        CODIGOGRUPOPRODUTO               DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 1                90013011         Cervejas Lager Tradicionais       10001628
# ...

# %% [markdown]
# ### Filtrando um tipo de faturamento específico

# %%
base_vendas[base_vendas["DESCRICAOTIPOFATURAMENTO"] == "VENDA"]
# Out:
#       DATAEMISSAO  CODIGOCLIENTE              DESCRICAOCLIENTE  \
# 0      2026-02-01       10000449          ATACADO BRINDE & CIA
# 1      2026-02-01       10000449          ATACADO BRINDE & CIA
# 2      2026-02-01       10000449          ATACADO BRINDE & CIA
# 3      2026-02-01       10000449          ATACADO BRINDE & CIA
# 4      2026-02-01       10000449          ATACADO BRINDE & CIA
# ...           ...            ...                           ...
# 43117  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43118  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43119  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43120  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43121  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
#
#        CODIGOGRUPOPRODUTO             DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 0                90013006    Bebidas Funcionais Vitaminadas       10022282
# ...

# %% [markdown]
# ### Combinando duas condições

# %%
base_vendas[(base_vendas["VALORLIQUIDO"] > 1000) & (base_vendas["VOLUME"] > 10)]
# Out:
#       DATAEMISSAO  CODIGOCLIENTE              DESCRICAOCLIENTE  \
# 1      2026-02-01       10000449          ATACADO BRINDE & CIA
# 4      2026-02-01       10000449          ATACADO BRINDE & CIA
# 6      2026-02-01       10000449          ATACADO BRINDE & CIA
# 21     2026-02-01       10000449          ATACADO BRINDE & CIA
# 38     2026-02-01       10000964   LOGÍSTICA ESSENCIAL BEBIDAS
# ...           ...            ...                           ...
# 43109  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43110  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43111  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43115  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43116  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
#
#        CODIGOGRUPOPRODUTO             DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 1                90013011       Cervejas Lager Tradicionais       10001628
# ...

# %% [markdown]
# # 7. Usando query()
#
# O **query()** permite escrever filtros de forma mais próxima de uma expressão textual.

# %%
base_vendas.query("VALORLIQUIDO > 1000")
# Out:
#       DATAEMISSAO  CODIGOCLIENTE              DESCRICAOCLIENTE  \
# 1      2026-02-01       10000449          ATACADO BRINDE & CIA
# 4      2026-02-01       10000449          ATACADO BRINDE & CIA
# 5      2026-02-01       10000449          ATACADO BRINDE & CIA
# 6      2026-02-01       10000449          ATACADO BRINDE & CIA
# 8      2026-02-01       10000449          ATACADO BRINDE & CIA
# ...           ...            ...                           ...
# 43116  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43117  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43118  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43119  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43120  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
#
#        CODIGOGRUPOPRODUTO               DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 1                90013011         Cervejas Lager Tradicionais       10001628
# ...

# %% [markdown]
# Também podemos combinar condições.

# %%
base_vendas.query("VALORLIQUIDO > 1000 and VOLUME > 10")
# Out:
#       DATAEMISSAO  CODIGOCLIENTE              DESCRICAOCLIENTE  \
# 1      2026-02-01       10000449          ATACADO BRINDE & CIA
# 4      2026-02-01       10000449          ATACADO BRINDE & CIA
# 6      2026-02-01       10000449          ATACADO BRINDE & CIA
# 21     2026-02-01       10000449          ATACADO BRINDE & CIA
# 38     2026-02-01       10000964   LOGÍSTICA ESSENCIAL BEBIDAS
# ...           ...            ...                           ...
# 43109  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43110  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43111  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43115  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
# 43116  2026-02-28       10005002  DISTRIBUIDORA ATLETA BEBIDAS
#
#        CODIGOGRUPOPRODUTO             DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 1                90013011       Cervejas Lager Tradicionais       10001628
# ...

# %% [markdown]
# # 8. Usando unique()
#
# O **unique()** mostra os valores únicos de uma coluna.

# %%
base_vendas["TIPOFATURAMENTO"].unique()
# Out:
# array([  1,   7,   8,   3,   2,  14,  13,   5,   6, 100,  82])

# %% [markdown]
# # 9. Usando value_counts()
#
# O **value_counts()** conta quantas vezes cada valor aparece.

# %%
base_vendas["TIPOFATURAMENTO"].value_counts()
# Out:
# TIPOFATURAMENTO
# 1      36476
# 3       2552
# 8       1630
# 13       911
# 2        671
# 7        578
# 5        137
# 100       62
# 6         60
# 82        34
# 14        11
# Name: count, dtype: int64

# %% [markdown]
# Também podemos usar em outras colunas categóricas.

# %%
base_vendas["DESCRICAOGRUPOPRODUTO"].value_counts()
# Out:
# DESCRICAOGRUPOPRODUTO
# Bebidas Mistas Alcoólicas                10523
# Bebidas Prontas para Consumo (RTD)        3888
# Bebidas Energéticas Funcionais            3053
# Bebidas Gasosas Saborizadas               2798
# Bebidas Energéticas Premium               2522
# Sucos Naturais Premium                    2351
# Bebidas Prontas Geladas                   2019
# Bebidas Funcionais Vitaminadas            1716
# Vinhos Tintos Importados                  1539
# Cervejas Artesanais Lupuladas             1501
# Refrigerantes Sabor Cola                  1371
# Cervejas Puro Malte                       1289
# Cervejas Especiais de Trigo               1076
# Cervejas Artesanais Premium                925
# Insumos para Produção de Bebidas           825
# Cervejas Lager Tradicionais                821
# Destilados Premium                         753
# Cervejas Regionais                         732
# Refrigerantes Sabor Frutas                 452
# ...

# %% [markdown]
# # 10. Usando sort_values()
#
# O **sort_values()** ordena os dados por uma ou mais colunas.
#
# ### Ordenando do menor para o maior valor líquido

# %%
base_vendas.sort_values("VALORLIQUIDO")
# Out:
#       DATAEMISSAO  CODIGOCLIENTE               DESCRICAOCLIENTE  \
# 7339   2026-02-06       10004228       SUPRIMENTOS BRINDE UNIDO
# 41042  2026-02-28       10000449           ATACADO BRINDE & CIA
# 7343   2026-02-06       10004228       SUPRIMENTOS BRINDE UNIDO
# 11429  2026-02-08       10004232        COMERCIAL ALPHA BEBIDAS
# 7341   2026-02-06       10004228       SUPRIMENTOS BRINDE UNIDO
# ...           ...            ...                            ...
# 31166  2026-02-21       10004227  LOGÍSTICA INTEGRAL DE BEBIDAS
# 25772  2026-02-17       10004209   DISTRIBUIDORA VIDA DE BEBIDA
# 20939  2026-02-15       10000964    LOGÍSTICA ESSENCIAL BEBIDAS
# 21005  2026-02-15       10000964    LOGÍSTICA ESSENCIAL BEBIDAS
# 20988  2026-02-15       10000964    LOGÍSTICA ESSENCIAL BEBIDAS
#
#        CODIGOGRUPOPRODUTO               DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 7339             90013172           Bebidas Mistas Alcoólicas       10015850
# ...

# %% [markdown]
# ### Ordenando do maior para o menor valor líquido

# %%
base_vendas.sort_values("VALORLIQUIDO", ascending=False)
# Out:
#       DATAEMISSAO  CODIGOCLIENTE               DESCRICAOCLIENTE  \
# 20988  2026-02-15       10000964    LOGÍSTICA ESSENCIAL BEBIDAS
# 21005  2026-02-15       10000964    LOGÍSTICA ESSENCIAL BEBIDAS
# 20939  2026-02-15       10000964    LOGÍSTICA ESSENCIAL BEBIDAS
# 25772  2026-02-17       10004209   DISTRIBUIDORA VIDA DE BEBIDA
# 31166  2026-02-21       10004227  LOGÍSTICA INTEGRAL DE BEBIDAS
# ...           ...            ...                            ...
# 7341   2026-02-06       10004228       SUPRIMENTOS BRINDE UNIDO
# 11429  2026-02-08       10004232        COMERCIAL ALPHA BEBIDAS
# 7343   2026-02-06       10004228       SUPRIMENTOS BRINDE UNIDO
# 41042  2026-02-28       10000449           ATACADO BRINDE & CIA
# 7339   2026-02-06       10004228       SUPRIMENTOS BRINDE UNIDO
#
#        CODIGOGRUPOPRODUTO               DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 20988            90013159                 Cervejas Puro Malte       10002818
# ...

# %% [markdown]
# ### Ordenando por mais de uma coluna

# %%
base_vendas.sort_values(["TIPOFATURAMENTO", "VALORLIQUIDO"], ascending=[True, False])
# Out:
#       DATAEMISSAO  CODIGOCLIENTE                 DESCRICAOCLIENTE  \
# 5301   2026-02-05       10000449             ATACADO BRINDE & CIA
# 42684  2026-02-28       10004231  DISTRIBUIDORA REINO DAS BEBIDAS
# 25154  2026-02-17       10004001         LOGÍSTICA GARRAFAS & LOG
# 12979  2026-02-09       10004221    DISTRIBUIDORA BRINDE & AMIGOS
# 40243  2026-02-27       10004221    DISTRIBUIDORA BRINDE & AMIGOS
# ...           ...            ...                              ...
# 1944   2026-02-02       10004007         LOGÍSTICA GUARDA BEBIDAS
# 39496  2026-02-27       10004004    CENTRAL DE NUTRIÇÃO E BEBIDAS
# 39493  2026-02-27       10004004    CENTRAL DE NUTRIÇÃO E BEBIDAS
# 39491  2026-02-27       10004004    CENTRAL DE NUTRIÇÃO E BEBIDAS
# 2268   2026-02-02       10004209     DISTRIBUIDORA VIDA DE BEBIDA
#
#        CODIGOGRUPOPRODUTO           DESCRICAOGRUPOPRODUTO  CODIGOPRODUTO  \
# 5301             90013006  Bebidas Funcionais Vitaminadas       10022283
# ...
